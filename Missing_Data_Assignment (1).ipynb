# %% [markdown]
# ### Import your libraries

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load your dataset

# %%
Data = pd.read_csv('C:/Users/alsow/Downloads/HR_Missing_Values.csv')

# %% [markdown]
# ### Explore your data
#
# * First 5 recods
# * Last 5 records
# * Check data type
# * Show statistical summary
# * Is there any missing values ?
# * Applay two more data analysis from your choose

# %%
Data.head()
# Out:
#               Employee_Name  EmpID    Salary  PositionID  \
# 0       Adinolfi, Wilson  K  10026   62506.0          19
# 1  Ait Sidi, Karthikeyan     10084  104437.0          27
# 2         Akinkuolie, Sarah  10196   64955.0          20
# 3              Alagbe,Trina  10088   64991.0          19
# 4                         0  10069   50825.0          19
#
#                    Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0   Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                   Sr. DBA  05/05/75  M      Married    White  3/30/2015
# 2  Production Technician II  09/19/88   F     Married    White   7/5/2011
# 3   Production Technician I       NaN   F     Married    White   1/7/2008
# 4   Production Technician I  09/08/89   F    Divorced    White  7/11/2011
#
#   DateofTermination         Department     ManagerName  ManagerID  \
# 0               NaN  Production         Michael Albert       22.0
# ...

# %%
Data.tail()
# Out:
#           Employee_Name  EmpID    Salary  PositionID  \
# 306      Woodson, Jason  10135   65893.0          20
# 307  Ybarra, Catherine   10301   48513.0          19
# 308                 NaN  10010  220450.0           6
# 309         Zhou, Julia  10043   89292.0           9
# 310                 NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 306  Production Technician II  05/11/85  M       Single    White   7/7/2014
# 307   Production Technician I       NaN   F      Single    Asian   9/2/2008
# 308                       CIO       NaN   F      Single    White  4/10/2010
# 309              Data Analyst  02/24/79   F      Single    White  3/30/2015
# 310   Production Technician I  08/17/78   F     Widowed    Asian  9/29/2014
#
#     DateofTermination         Department     ManagerName  ManagerID  \
# 306               NaN  Production         Kissy Sullivan       20.0
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_Name      218 non-null    object
#  1   EmpID              311 non-null    int64
#  2   Salary             249 non-null    float64
#  3   PositionID         311 non-null    int64
#  4   Position           311 non-null    object
#  5   DOB                280 non-null    object
#  6   Sex                249 non-null    object
#  7   MaritalDesc        311 non-null    object
#  8   RaceDesc           311 non-null    object
#  9   DateofHire         311 non-null    object
#  10  DateofTermination  104 non-null    object
#  11  Department         311 non-null    object
#  12  ManagerName        311 non-null    object
#  13  ManagerID          303 non-null    float64
#  14  RecruitmentSource  311 non-null    object
#  15  Absences           280 non-null    float64
# ...

# %%
Data.describe().T
# Out:
#             count          mean           std      min       25%      50%  \
# EmpID       311.0  10156.000000     89.922189  10001.0  10078.50  10156.0
# Salary      249.0  67972.662651  22995.908395  45046.0  55315.00  62957.0
# PositionID  311.0     16.845659      6.223419      1.0     18.00     19.0
# ManagerID   303.0     14.570957      8.078306      1.0     10.00     15.0
# Absences    280.0     10.128571      5.946407      1.0      4.75     10.0
#
#                  75%       max
# EmpID       10233.50   10311.0
# Salary      71707.00  220450.0
# PositionID     20.00      30.0
# ManagerID      19.00      39.0
# Absences       15.25      20.0

# %%
Data.isnull().sum()
#Yes, we have null values on data.
# Out:
# Employee_Name         93
# EmpID                  0
# Salary                62
# PositionID             0
# Position               0
# DOB                   31
# Sex                   62
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination    207
# Department             0
# ManagerName            0
# ManagerID              8
# RecruitmentSource      0
# Absences              31
# dtype: int64

# %%
Fig = Data.isnull().sum().sort_values().plot(kind="barh", title="Missing Data in Each Column");

#This figure shows each column and how many null values. We see that DateofTermination is the most column has null values.

# %%
Data['Sex'].value_counts().plot(kind='bar')
#We see here that female emplyees more than male
# Out:
# <Axes: >

# %% [markdown]
# ### Do the following steps for each column with missing values.
#
# * Identity the column
# * How much precentage the missing value represents
# * What is the best way to handle these missing values and why
# * Apply your method to the column

# %% [markdown]
# ### First Column: Employee_Name

# %%
Data['Employee_Name'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 306    False
# 307    False
# 308     True
# 309    False
# 310     True
# Name: Employee_Name, Length: 311, dtype: bool

# %%
Data['Employee_Name'].isnull().sum()
# Out:
# 93

# %%
print('The percentage of null values for this column: ', Data['Employee_Name'].isnull().sum()*100/len(Data))
# Out:
# The percentage of null values for this column:  29.90353697749196

# %% [markdown]
# #### The percentage of null values in this column : 29.90% over all rows which is high percentage compared to the table.(Employee_Name) is represent names of employees, so it can be iterable with first name or last, or somme cases both same.But in this case we can't iterate the value or take the previous value, because the name is specially unique. We can't drop the values, because we will not get any benefit of dropping the name!  On my opinion, full the Null Values with (Unknown) word.

# %%
Data['Employee_Name'] = Data['Employee_Name'].fillna('Unknown')
Data
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                     Unknown  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                   Unknown  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                   Unknown  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %% [markdown]
# ### Second Column: ٍSalary

# %%
Data['Salary'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Name: Salary, Length: 311, dtype: bool

# %%
Data['Salary'].isnull().sum()
# Out:
# 62

# %%
print('The percentage of null values for this column: ',Data['Salary'].isnull().sum()*100/len(Data))
# Out:
# The percentage of null values for this column:  19.935691318327976

# %%
Data.Salary.plot(kind="hist", bins=20, title="Salary Distribution");

# %%
print('Variance of Salary and Average: ', Data.Salary.var(), ',',Data.Salary.mean())
# Out:
# Variance of Salary and Average:  528811802.89380103 , 67972.6626506024

# %%
Data.Salary = Data.Salary.fillna(Data.Salary.mean())
Data.Salary.isnull().sum()
# Out:
# 0

# %%
Data.Salary.plot(kind="hist", bins=20, title="Salary Distribution");

# %% [markdown]
# #### Analysis:
# The percentage of null values in this column : 19.93% over all rows which is medium percentage compared to the table. In the begnning, I want to put a salary for each non salary value depending on employee position, but I took a tour with all salaries, I found: some of employees have same position, but the salary for each one is different! so I suggest to handle these null values with take the mean of Salary columns and replace the new value to all null values. As previous, the small changes in first and second charts is noticed!

# %% [markdown]
# ### Third Column: DOB

# %%
Data['DOB'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 306    False
# 307     True
# 308     True
# 309    False
# 310    False
# Name: DOB, Length: 311, dtype: bool

# %%
Data['DOB'].isnull().sum()
# Out:
# 31

# %%
Data['DOB'].isnull().sum()*100/len(Data)
# Out:
# 9.967845659163988

# %%
Data['DOB'].dropna()

Data

# Dropping a date of birth is suitable because its not valuable to let the dates NaN, or take the previous values! 
# Its not working!
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                     Unknown  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                   Unknown  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                   Unknown  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %% [markdown]
# ### Third Column: Sex

# %%
Data['Sex'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309    False
# 310    False
# Name: Sex, Length: 311, dtype: bool

# %%
Data['Sex'].isnull().sum()
# Out:
# 62

# %%
print('The percentage of null values for this column: ', Data['Sex'].isnull().sum()*100/len(Data))
# Out:
# The percentage of null values for this column:  19.935691318327976

# %%
def SexIdentifier(): 
    for i, row in Data.iterrows():
        if pd.isnull(row['Sex']):
            if row['Salary'] < grouped['F']:
                Data.at[i, 'Sex'] = 'F'
            else:
                Data.at[i, 'Sex'] = 'M'

Data.fillna(SexIdentifier)
Data
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                           0  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                         0  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                         0  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...

# %% [markdown]
# #### The approach used here is I calaculate the mean of salary for each female, and male, then creating a function to read each row of sex column, when it is null and for example 'F', go to salary and check if its less than mean of salary for female, and the same approach for male.

# %% [markdown]
# ### Fourth Column: DateOfTermination

# %%
Data['DateofTermination'].isnull()
# Out:
# 0       True
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 306     True
# 307    False
# 308     True
# 309     True
# 310     True
# Name: DateofTermination, Length: 311, dtype: bool

# %%
Data['DateofTermination'].isnull().sum()
# Out:
# 207

# %%
print('The percentage of null values for this column: ', Data['DateofTermination'].isnull().sum()*100/len(Data))
# Out:
# The percentage of null values for this column:  66.55948553054662

# %%
Data['DateofTermination'].fillna(method = "bfill")


#Convert Null values Date with Background Filling Date
# Out:
# 0      2015-09-22 00:00:00
# 1                6/16/2016
# 2                9/24/2012
# 3      2015-09-22 00:00:00
# 4                 9/6/2016
#               ...
# 306    2015-09-22 00:00:00
# 307              9/29/2015
# 308    2015-09-22 00:00:00
# 309    2015-09-22 00:00:00
# 310    2015-09-22 00:00:00
# Name: DateofTermination, Length: 311, dtype: object

# %% [markdown]
# ### Fifth Column: Absences

# %%
Data['Absences'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 306    False
# 307    False
# 308    False
# 309     True
# 310    False
# Name: Absences, Length: 311, dtype: bool

# %%
Data['Absences'].isnull().sum()
# Out:
# 31

# %%
print('The percentage of null values for this column: ', Data['Absences'].isnull().sum()*100/len(Data))
# Out:
# The percentage of null values for this column:  9.967845659163988

# %%
Data['Absences'] = Data['Absences'].fillna(0)
Data 



# Set all null values in absences to 0. Logically, When the employee doesn't had an absences so set it to zero.
# Out:
#                 Employee_Name  EmpID    Salary  PositionID  \
# 0         Adinolfi, Wilson  K  10026   62506.0          19
# 1    Ait Sidi, Karthikeyan     10084  104437.0          27
# 2           Akinkuolie, Sarah  10196   64955.0          20
# 3                Alagbe,Trina  10088   64991.0          19
# 4                     Unknown  10069   50825.0          19
# ..                        ...    ...       ...         ...
# 306            Woodson, Jason  10135   65893.0          20
# 307        Ybarra, Catherine   10301   48513.0          19
# 308                   Unknown  10010  220450.0           6
# 309               Zhou, Julia  10043   89292.0           9
# 310                   Unknown  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0     Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                     Sr. DBA  05/05/75  M      Married    White  3/30/2015
# ...
