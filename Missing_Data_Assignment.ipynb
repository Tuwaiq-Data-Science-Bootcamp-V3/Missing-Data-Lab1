# %% [markdown]
# ### Import your libraries

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load your dataset

# %%
df = pd.read_csv('HR_Missing_Values.csv')

# %% [markdown]
# ### Explore your data
#
# * First 5 recods
# * Last 5 records
# * Check data type
# * Show statistical summary
# * Is there any missing values ?
# * Applay two more data analysis from your choose

# %%
df.head()
# Out:
#               Employee_Name  EmpID    Salary  PositionID  \
# 0       Adinolfi, Wilson  K  10026   62506.0          19
# 1  Ait Sidi, Karthikeyan     10084  104437.0          27
# 2         Akinkuolie, Sarah  10196   64955.0          20
# 3              Alagbe,Trina  10088   64991.0          19
# 4                       NaN  10069   50825.0          19
#
#                    Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 0   Production Technician I  07/10/83  M       Single    White   7/5/2011
# 1                   Sr. DBA  05/05/75  M      Married    White  3/30/2015
# 2  Production Technician II  09/19/88   F     Married    White   7/5/2011
# 3   Production Technician I       NaN   F     Married    White   1/7/2008
# 4   Production Technician I  09/08/89   F    Divorced    White  7/11/2011
#
#   DateofTermination         Department     ManagerName  ManagerID  \
# 0               NaN  Production         Michael Albert       22.0
# ...

# %%
df.tail()
# Out:
#           Employee_Name  EmpID    Salary  PositionID  \
# 306      Woodson, Jason  10135   65893.0          20
# 307  Ybarra, Catherine   10301   48513.0          19
# 308                 NaN  10010  220450.0           6
# 309         Zhou, Julia  10043   89292.0           9
# 310                 NaN  10271   45046.0          19
#
#                      Position       DOB Sex MaritalDesc RaceDesc DateofHire  \
# 306  Production Technician II  05/11/85  M       Single    White   7/7/2014
# 307   Production Technician I       NaN   F      Single    Asian   9/2/2008
# 308                       CIO       NaN   F      Single    White  4/10/2010
# 309              Data Analyst  02/24/79   F      Single    White  3/30/2015
# 310   Production Technician I  08/17/78   F     Widowed    Asian  9/29/2014
#
#     DateofTermination         Department     ManagerName  ManagerID  \
# 306               NaN  Production         Kissy Sullivan       20.0
# ...

# %%
df.dtypes
# Out:
# Employee_Name         object
# EmpID                  int64
# Salary               float64
# PositionID             int64
# Position              object
# DOB                   object
# Sex                   object
# MaritalDesc           object
# RaceDesc              object
# DateofHire            object
# DateofTermination     object
# Department            object
# ManagerName           object
# ManagerID            float64
# RecruitmentSource     object
# Absences             float64
# dtype: object

# %%
df.describe()
# Out:
#               EmpID         Salary  PositionID   ManagerID    Absences
# count    311.000000     249.000000  311.000000  303.000000  280.000000
# mean   10156.000000   67972.662651   16.845659   14.570957   10.128571
# std       89.922189   22995.908395    6.223419    8.078306    5.946407
# min    10001.000000   45046.000000    1.000000    1.000000    1.000000
# 25%    10078.500000   55315.000000   18.000000   10.000000    4.750000
# 50%    10156.000000   62957.000000   19.000000   15.000000   10.000000
# 75%    10233.500000   71707.000000   20.000000   19.000000   15.250000
# max    10311.000000  220450.000000   30.000000   39.000000   20.000000

# %%
df.isna().sum()
# Out:
# Employee_Name         93
# EmpID                  0
# Salary                62
# PositionID             0
# Position               0
# DOB                   31
# Sex                   62
# MaritalDesc            0
# RaceDesc               0
# DateofHire             0
# DateofTermination    207
# Department             0
# ManagerName            0
# ManagerID              8
# RecruitmentSource      0
# Absences              31
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_Name      218 non-null    object
#  1   EmpID              311 non-null    int64
#  2   Salary             249 non-null    float64
#  3   PositionID         311 non-null    int64
#  4   Position           311 non-null    object
#  5   DOB                280 non-null    object
#  6   Sex                249 non-null    object
#  7   MaritalDesc        311 non-null    object
#  8   RaceDesc           311 non-null    object
#  9   DateofHire         311 non-null    object
#  10  DateofTermination  104 non-null    object
#  11  Department         311 non-null    object
#  12  ManagerName        311 non-null    object
#  13  ManagerID          303 non-null    float64
#  14  RecruitmentSource  311 non-null    object
#  15  Absences           280 non-null    float64
# ...

# %%
df.shape
# Out:
# (311, 16)

# %%
df.var()
# Out:
# C:\Users\HANADI\AppData\Local\Temp\ipykernel_13616\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# EmpID         8.086000e+03
# Salary        5.288118e+08
# PositionID    3.873094e+01
# ManagerID     6.525902e+01
# Absences      3.535975e+01
# dtype: float64

# %% [markdown]
# ### Do the following steps for each column with missing values.
#
# * Identity the column
# * How much precentage the missing value represents
# * What is the best way to handle these missing values and why
# * Apply your method to the column

# %%
# !pip install missingno
import missingno as msno
msno.matrix(df);

# %%
perc = df.isna().sum()/len(df) * 100

print(f'Percentage of missing values\n{perc}')
# Out:
# Percentage of missing values
# Employee_Name        29.903537
# EmpID                 0.000000
# Salary               19.935691
# PositionID            0.000000
# Position              0.000000
# DOB                   9.967846
# Sex                  19.935691
# MaritalDesc           0.000000
# RaceDesc              0.000000
# DateofHire            0.000000
# DateofTermination    66.559486
# Department            0.000000
# ManagerName           0.000000
# ManagerID             2.572347
# RecruitmentSource     0.000000
# Absences              9.967846
# dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False).plot(kind="bar", title="Missing Data");

# %%
df.drop(['DateofTermination'], axis=1, inplace=True)

df['Employee_Name'] = df['Employee_Name'].fillna('Na')

df.isnull().sum().sort_values(ascending=False).plot(kind="bar", title="Missing Data");

# %%
df['Sex'] = df['Sex'].fillna('Na')

# %%
df['Salary'].var()
# Out:
# 528811802.89380103

# %%
df.Salary.plot(kind="hist", bins=20, title="Salary Distribution");

# %%
grouped_salary = df.groupby(['Position']).agg({'Salary': 'mean'})
df['Salary'] = df['Salary'].fillna(df['Position'].map(grouped_salary['Salary']))
grouped_salary
# Out:
#                                      Salary
# Position
# Accountant I                   63507.666667
# Administrative Assistant       52280.000000
# Area Sales Manager             64245.272727
# BI Developer                   95465.000000
# BI Director                   110929.000000
# CIO                           220450.000000
# Data Analyst                   89932.571429
# Data Analyst                            NaN
# Data Architect                          NaN
# Database Administrator        107124.750000
# Director of Operations        170500.000000
# Director of Sales             180000.000000
# Enterprise Architect                    NaN
# IT Director                   178000.000000
# IT Manager - DB                         NaN
# IT Manager - Infra            157000.000000
# IT Manager - Support          138888.000000
# IT Support                     65431.750000
# Network Engineer               61605.000000
# President & CEO                         NaN
# ...

# %%
grouped_salary_dep = df.groupby(['Department']).agg({'Salary': 'mean'})
df['Salary'] = df['Salary'].fillna(df['Department'].map(grouped_salary_dep['Salary']))
grouped_salary_dep
# Out:
#                             Salary
# Department
# Admin Offices         69135.125000
# Executive Office               NaN
# IT/IS                 93859.222222
# Production            59880.049245
# Sales                 68462.656891
# Software Engineering  95325.131313

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
df.Salary.plot(kind="hist", bins=20, title="Salary Distribution");

# %%
df['Salary'].var()
# Out:
# 462605235.9995116

# %%
df.isnull().sum().sort_values(ascending=False).plot(kind="bar", title="Missing Data");

# %%
df.drop(['DOB'], axis=1, inplace=True)
df['Absences'] = df['Absences'].fillna(0)
df.isnull().sum().sort_values(ascending=False).plot(kind="bar", title="Missing Data");

# %%
grouped_Man = df.groupby(['ManagerName']).agg({'ManagerID': 'unique'})
grouped_Man
# Out:
#                        ManagerID
# ManagerName
# Alex Sweetwater           [10.0]
# Amy Dunn                  [11.0]
# Board of Directors         [9.0]
# Brandon R. LeBlanc    [3.0, 1.0]
# Brannon Miller            [12.0]
# Brian Champaigne          [13.0]
# David Stanley             [14.0]
# Debra Houlihan            [15.0]
# Elijiah Gray              [16.0]
# Eric Dougall               [6.0]
# Janet King                 [2.0]
# Jennifer Zamora            [5.0]
# John Smith                [17.0]
# Kelley Spirea             [18.0]
# Ketsia Liebig             [19.0]
# Kissy Sullivan            [20.0]
# Lynn Daneault             [21.0]
# Michael Albert      [22.0, 30.0]
# Peter Monroe               [7.0]
# Simon Roup                 [4.0]
# Webster Butler       [39.0, nan]

# %%
df['ManagerID'] = df['ManagerID'].fillna(39)

# %%
df.isnull().sum().sort_values(ascending=False).plot(kind="bar", title="Missing Data");

# %%
df.var()
# Out:
# C:\Users\HANADI\AppData\Local\Temp\ipykernel_13616\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# EmpID         8.086000e+03
# Salary        4.626052e+08
# PositionID    3.873094e+01
# ManagerID     7.857948e+01
# Absences      4.105999e+01
# dtype: float64
